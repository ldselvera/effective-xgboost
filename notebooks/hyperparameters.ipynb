# %% [markdown]
# ## Datasets

# %%
import pandas as pd
import matplotlib.pyplot as plt
import urllib.request
import zipfile
import xgboost as xgb

# %%
from feature_engine import encoding, imputation
from sklearn import model_selection
from sklearn import dummy
from sklearn import preprocessing
from sklearn import tree
from sklearn import base, pipeline

# %%
url = 'https://github.com/mattharrison/datasets/raw/master/data/'\
    'kaggle-survey-2018.zip'
fname = '../data/kaggle-survey-2018.zip'
member_name = 'multipleChoiceResponses.csv'

# %%
def extract_zip(src, dst, member_name):
    """Extract a member file from a zip file and read it into a pandas 
    DataFrame.
    
    Parameters:
        src (str): URL of the zip file to be downloaded and extracted.
        dst (str): Local file path where the zip file will be written.
        member_name (str): Name of the member file inside the zip file 
            to be read into a DataFrame.
    
    Returns:
        pandas.DataFrame: DataFrame containing the contents of the 
            member file.
    """    
    url = src
    fname = dst
    fin = urllib.request.urlopen(url)
    data = fin.read()
    with open(dst, mode='wb') as fout:
        fout.write(data)
    with zipfile.ZipFile(dst) as z:
        kag = pd.read_csv(z.open(member_name))
        kag_questions = kag.iloc[0]
        raw = kag.iloc[1:]
        return raw

# %%
raw = extract_zip(url, fname, member_name)
# Out:
# /tmp/ipykernel_368/1222519436.py:22: DtypeWarning: Columns (0,2,8,10,21,23,24,25,26,27,28,42,44,54,56,64,81,83,85,87,105,107,109,121,123,125,148,150,157,172,174,192,194,210,218,219,221,223,246,247,249,262,264,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,302,304,306,325,326,329,341,368,371,384,385,389,390,391,393,394) have mixed types. Specify dtype option on import or set low_memory=False.
#   kag = pd.read_csv(z.open(member_name))

# %%
type(raw)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Cleanup Pipeline

# %%
def tweak_kag(df_: pd.DataFrame) -> pd.DataFrame:
    """
    Tweak the Kaggle survey data and return a new DataFrame.

    This function takes a Pandas DataFrame containing Kaggle 
    survey data as input and returns a new DataFrame. The 
    modifications include extracting and transforming certain 
    columns, renaming columns, and selecting a subset of columns.

    Parameters
    ----------
    df_ : pd.DataFrame
        The input DataFrame containing Kaggle survey data.

    Returns
    -------
    pd.DataFrame
        The new DataFrame with the modified and selected columns.
    """    
    return (df_
            .assign(age=df_.Q2.str.slice(0,2).astype(int),
                    education=df_.Q4.replace({'Master’s degree': 18,
                         'Bachelor’s degree': 16,
                         'Doctoral degree': 20,
'Some college/university study without earning a bachelor’s degree': 13,
                         'Professional degree': 19,
                         'I prefer not to answer': None,
                         'No formal education past high school': 12}),
                    major=(df_.Q5
                              .pipe(topn, n=3)
                              .replace({
                        'Computer science (software engineering, etc.)': 'cs',
                        'Engineering (non-computer focused)': 'eng',
                        'Mathematics or statistics': 'stat'})
                         ),
                    years_exp=(df_.Q8.str.replace('+','', regex=False)
                           .str.split('-', expand=True)
                           .iloc[:,0]
                           .astype(float)),
                    compensation=(df_.Q9.str.replace('+','', regex=False)
                           .str.replace(',','', regex=False)
                           .str.replace('500000', '500', regex=False)
  .str.replace('I do not wish to disclose my approximate yearly compensation',
             '0', regex=False)
                           .str.split('-', expand=True)
                           .iloc[:,0]
                           .fillna(0)
                           .astype(int)
                           .mul(1_000)
                                    ),
                    python=df_.Q16_Part_1.fillna(0).replace('Python', 1),
                    r=df_.Q16_Part_2.fillna(0).replace('R', 1),
                    sql=df_.Q16_Part_3.fillna(0).replace('SQL', 1)
               )#assign
        .rename(columns=lambda col:col.replace(' ', '_'))
        .loc[:, 'Q1,Q3,age,education,major,years_exp,compensation,'
                'python,r,sql'.split(',')]   
       )

# %%
def topn(ser, n=5, default='other'):
    """
    Replace all values in a Pandas Series that are not among 
    the top `n` most frequent values with a default value.

    This function takes a Pandas Series and returns a new 
    Series with the values replaced as described above. The 
    top `n` most frequent values are determined using the 
    `value_counts` method of the input Series.

    Parameters
    ----------
    ser : pd.Series
        The input Series.
    n : int, optional
        The number of most frequent values to keep. The 
        default value is 5.
    default : str, optional
        The default value to use for values that are not among 
        the top `n` most frequent values. The default value is 
        'other'.

    Returns
    -------
    pd.Series
        The modified Series with the values replaced.
    """    
    counts = ser.value_counts()
    return ser.where(ser.isin(counts.index[:n]), default)

# %%
class TweakKagTransformer(base.BaseEstimator,
    base.TransformerMixin):
    """
    A transformer for tweaking Kaggle survey data.

    This transformer takes a Pandas DataFrame containing 
    Kaggle survey data as input and returns a new version of 
    the DataFrame. The modifications include extracting and 
    transforming certain columns, renaming columns, and 
    selecting a subset of columns.

    Parameters
    ----------
    ycol : str, optional
        The name of the column to be used as the target variable. 
        If not specified, the target variable will not be set.

    Attributes
    ----------
    ycol : str
        The name of the column to be used as the target variable.
    """
    
    def __init__(self, ycol=None):
        self.ycol = ycol
        
    def transform(self, X):
        return tweak_kag(X)
    
    def fit(self, X, y=None):
        return self

# %%
def get_rawX_y(df, y_col):
    raw = (df
            .query('Q3.isin(["United States of America", "China", "India"]) '
               'and Q6.isin(["Data Scientist", "Software Engineer"])')
          )
    return raw.drop(columns=[y_col]), raw[y_col]

# %%
## Create a pipeline
kag_pl = pipeline.Pipeline(
    [('tweak', TweakKagTransformer()),
     ('cat', encoding.OneHotEncoder(top_categories=5, drop_last=True, 
           variables=['Q1', 'Q3', 'major'])),
     ('num_impute', imputation.MeanMedianImputer(imputation_method='median',
          variables=['education', 'years_exp']))]
)

# %%
kag_X, kag_y = get_rawX_y(raw, 'Q6')

kag_X_train, kag_X_test, kag_y_train, kag_y_test = \
    model_selection.train_test_split(
        kag_X, kag_y, test_size=.3, random_state=42, stratify=kag_y)

X_train = kag_pl.fit_transform(kag_X_train, kag_y_train)
X_test = kag_pl.transform(kag_X_test)
# Out:
# /tmp/ipykernel_368/3991961449.py:22: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   education=df_.Q4.replace({'Master’s degree': 18,
# /tmp/ipykernel_368/3991961449.py:51: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   python=df_.Q16_Part_1.fillna(0).replace('Python', 1),
# /tmp/ipykernel_368/3991961449.py:52: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   r=df_.Q16_Part_2.fillna(0).replace('R', 1),
# /tmp/ipykernel_368/3991961449.py:53: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sql=df_.Q16_Part_3.fillna(0).replace('SQL', 1)
# /tmp/ipykernel_368/3991961449.py:22: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   education=df_.Q4.replace({'Master’s degree': 18,
# /tmp/ipykernel_368/3991961449.py:51: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   python=df_.Q16_Part_1.fillna(0).replace('Python', 1),
# /tmp/ipykernel_368/3991961449.py:52: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   r=df_.Q16_Part_2.fillna(0).replace('R', 1),
# /tmp/ipykernel_368/3991961449.py:53: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sql=df_.Q16_Part_3.fillna(0).replace('SQL', 1)

# %%
print(X_train)
# Out:
#        age  education  years_exp  compensation  python  r  sql  Q1_Male  \
# 587     25       18.0        4.0             0       1  0    1        1
# 3065    22       16.0        1.0         10000       1  0    0        1
# 8435    22       18.0        1.0             0       1  0    0        1
# 3110    40       20.0        3.0        125000       1  0    1        0
# 16372   45       12.0        5.0        100000       1  0    1        1
# ...    ...        ...        ...           ...     ... ..  ...      ...
# 16608   25       16.0        2.0         10000       0  0    1        1
# 7325    18       16.0        1.0         30000       1  0    1        1
# 21810   18       16.0        2.0             0       0  0    0        1
# 4917    25       18.0        1.0        100000       1  0    1        1
# 639     25       18.0        1.0         10000       1  0    0        0
#
#        Q1_Female  Q1_Prefer not to say  Q1_Prefer to self-describe  \
# 587            0                     0                           0
# 3065           0                     0                           0
# 8435           0                     0                           0
# 3110           1                     0                           0
# 16372          0                     0                           0
# ...          ...                   ...                         ...
# 16608          0                     0                           0
# 7325           0                     0                           0
# 21810          0                     0                           0
# 4917           0                     0                           0
# 639            1                     0                           0
#
#        Q3_United States of America  Q3_India  Q3_China  major_cs  major_other  \
# 587                              0         1         0         0            1
# 3065                             0         1         0         1            0
# 8435                             0         1         0         0            1
# 3110                             1         0         0         0            1
# 16372                            1         0         0         0            1
# ...                            ...       ...       ...       ...          ...
# 16608                            0         1         0         1            0
# 7325                             1         0         0         1            0
# 21810                            0         1         0         1            0
# 4917                             1         0         0         0            0
# 639                              0         1         0         1            0
#
#        major_eng  major_stat
# 587            0           0
# 3065           0           0
# 8435           0           0
# 3110           0           0
# 16372          0           0
# ...          ...         ...
# 16608          0           0
# 7325           0           0
# 21810          0           0
# 4917           0           1
# 639            0           0
#
# [2110 rows x 18 columns]

# %%
kag_y_train
# Out:
# 587      Software Engineer
# 3065        Data Scientist
# 8435        Data Scientist
# 3110        Data Scientist
# 16372    Software Engineer
#                ...
# 16608    Software Engineer
# 7325     Software Engineer
# 21810       Data Scientist
# 4917        Data Scientist
# 639         Data Scientist
# Name: Q6, Length: 2110, dtype: object

# %% [markdown]
# ## Model Complexity & Hyperparameters

# %%
# Overfitting
hi_variance = tree.DecisionTreeClassifier(max_depth=None)
X_train = kag_pl.fit_transform(kag_X_train)
hi_variance.fit(X_train, kag_y_train)
hi_variance.score(X_test, kag_y_test)
# Out:
# /tmp/ipykernel_368/3991961449.py:22: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   education=df_.Q4.replace({'Master’s degree': 18,
# /tmp/ipykernel_368/3991961449.py:51: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   python=df_.Q16_Part_1.fillna(0).replace('Python', 1),
# /tmp/ipykernel_368/3991961449.py:52: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   r=df_.Q16_Part_2.fillna(0).replace('R', 1),
# /tmp/ipykernel_368/3991961449.py:53: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sql=df_.Q16_Part_3.fillna(0).replace('SQL', 1)
# 0.6629834254143646

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)

tree.plot_tree(hi_variance, feature_names=features, filled=True)
# Out:
# [Text(0.659051522672214, 0.9761904761904762, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]'),
#  Text(0.4020244694017274, 0.9285714285714286, 'major_cs <= 0.5\ngini = 0.493\nsamples = 1484\nvalue = [653, 831]'),
#  Text(0.5305379960369707, 0.9523809523809523, 'True  '),
#  Text(0.19829629239519697, 0.8809523809523809, 'Q3_United States of America <= 0.5\ngini = 0.49\nsamples = 718\nvalue = [410, 308]'),
#  Text(0.08006372445755214, 0.8333333333333334, 'years_exp <= 0.5\ngini = 0.491\nsamples = 322\nvalue = [140, 182]'),
#  Text(0.025700442384664, 0.7857142857142857, 'education <= 17.0\ngini = 0.463\nsamples = 74\nvalue = [47, 27]'),
#  Text(0.01938066147040236, 0.7380952380952381, 'age <= 27.5\ngini = 0.499\nsamples = 40\nvalue = [21, 19]'),
#  Text(0.01769538655993259, 0.6904761904761905, 'major_stat <= 0.5\ngini = 0.5\nsamples = 38\nvalue = [19, 19]'),
#  Text(0.016010111649462817, 0.6428571428571429, 'compensation <= 55000.0\ngini = 0.498\nsamples = 36\nvalue = [17, 19]'),
#  Text(0.014324836738993048, 0.5952380952380952, 'compensation <= 15000.0\ngini = 0.5\nsamples = 35\nvalue = [17, 18]'),
#  Text(0.012639561828523278, 0.5476190476190477, 'python <= 0.5\ngini = 0.496\nsamples = 33\nvalue = [15, 18]'),
#  Text(0.008426374552348851, 0.5, 'age <= 23.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.005055824731409311, 0.4523809523809524, 'Q1_Female <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.0033705498209395408, 0.40476190476190477, 'age <= 20.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.0016852749104697704, 0.35714285714285715, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.005055824731409311, 0.35714285714285715, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0067410996418790815, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.011796924373288392, 0.4523809523809524, 'education <= 14.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.010111649462818622, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.013482199283758163, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.016852749104697702, 0.5, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 22\nvalue = [11, 11]'),
#  Text(0.015167474194227933, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.018538024015167475, 0.4523809523809524, 'Q3_China <= 0.5\ngini = 0.495\nsamples = 20\nvalue = [9, 11]'),
#  Text(0.016852749104697702, 0.40476190476190477, 'compensation <= 5000.0\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.012639561828523278, 0.35714285714285715, 'age <= 20.0\ngini = 0.469\nsamples = 16\nvalue = [6, 10]'),
#  Text(0.009269012007583738, 0.30952380952380953, 'education <= 14.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.007583737097113966, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.010954286918053507, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.016010111649462817, 0.30952380952380953, 'age <= 23.5\ngini = 0.426\nsamples = 13\nvalue = [4, 9]'),
#  Text(0.014324836738993048, 0.2619047619047619, 'sql <= 0.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.010954286918053507, 0.21428571428571427, 'major_other <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.009269012007583738, 0.16666666666666666, 'gini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.012639561828523278, 0.16666666666666666, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.01769538655993259, 0.21428571428571427, 'major_other <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.016010111649462817, 0.16666666666666666, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.01938066147040236, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01769538655993259, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.02106593638087213, 0.35714285714285715, 'age <= 20.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.01938066147040236, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0227512112913419, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.020223298925637245, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.016010111649462817, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.01769538655993259, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01938066147040236, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.02106593638087213, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.032020223298925635, 0.7380952380952381, 'sql <= 0.5\ngini = 0.36\nsamples = 34\nvalue = [26, 8]'),
#  Text(0.02612176111228144, 0.6904761904761905, 'compensation <= 5000.0\ngini = 0.269\nsamples = 25\nvalue = [21, 4]'),
#  Text(0.0227512112913419, 0.6428571428571429, 'Q3_India <= 0.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.02106593638087213, 0.5952380952380952, 'major_other <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.01938066147040236, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.0227512112913419, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.024436486201811672, 0.5952380952380952, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.02949231093322098, 0.6428571428571429, 'Q3_China <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.02780703602275121, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.031177585843690753, 0.5952380952380952, 'Q1_Male <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.02949231093322098, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03286286075416052, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.037918685485569835, 0.6904761904761905, 'compensation <= 5000.0\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.036233410575100065, 0.6428571428571429, 'age <= 20.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.034548135664630296, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.037918685485569835, 0.5952380952380952, 'age <= 23.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.036233410575100065, 0.5476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.039603960396039604, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.039603960396039604, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1344270065304403, 0.7857142857142857, 'major_stat <= 0.5\ngini = 0.469\nsamples = 248\nvalue = [93, 155]'),
#  Text(0.10432904992626922, 0.7380952380952381, 'education <= 17.0\ngini = 0.446\nsamples = 220\nvalue = [74, 146]'),
#  Text(0.06409311143880346, 0.6904761904761905, 'years_exp <= 1.5\ngini = 0.38\nsamples = 110\nvalue = [28.0, 82.0]'),
#  Text(0.05055824731409311, 0.6428571428571429, 'compensation <= 15000.0\ngini = 0.49\nsamples = 28\nvalue = [12, 16]'),
#  Text(0.048872972403623344, 0.5952380952380952, 'age <= 23.5\ngini = 0.444\nsamples = 24\nvalue = [8, 16]'),
#  Text(0.042974510216979143, 0.5476190476190477, 'python <= 0.5\ngini = 0.36\nsamples = 17\nvalue = [4, 13]'),
#  Text(0.039603960396039604, 0.5, 'age <= 20.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.037918685485569835, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.041289235306509374, 0.4523809523809524, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04634506003791868, 0.5, 'Q1_Prefer not to say <= 0.5\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.04465978512744891, 0.4523809523809524, 'sql <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.042974510216979143, 0.40476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.04634506003791868, 0.40476190476190477, 'major_other <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.04465978512744891, 0.35714285714285715, 'compensation <= 5000.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.042974510216979143, 0.30952380952380953, 'gini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.04634506003791868, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04803033494838846, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04803033494838846, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05477143459026754, 0.5476190476190477, 'compensation <= 5000.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.05308615967979777, 0.5, 'major_eng <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.051400884769328, 0.4523809523809524, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.04971560985885823, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.05308615967979777, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05477143459026754, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.05645670950073731, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.05224352222456288, 0.5952380952380952, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.07762797556351379, 0.6428571428571429, 'age <= 20.0\ngini = 0.314\nsamples = 82\nvalue = [16, 66]'),
#  Text(0.07594270065304402, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07931325047398356, 0.5952380952380952, 'age <= 45.0\ngini = 0.302\nsamples = 81\nvalue = [15, 66]'),
#  Text(0.07762797556351379, 0.5476190476190477, 'years_exp <= 4.5\ngini = 0.289\nsamples = 80\nvalue = [14, 66]'),
#  Text(0.06762165578259954, 0.5, 'age <= 23.5\ngini = 0.357\nsamples = 56\nvalue = [13, 43]'),
#  Text(0.058141984411207076, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.05645670950073731, 0.40476190476190477, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.059827259321676846, 0.40476190476190477, 'years_exp <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.058141984411207076, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06151253423214662, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.077101327153992, 0.4523809523809524, 'compensation <= 45000.0\ngini = 0.402\nsamples = 43\nvalue = [12.0, 31.0]'),
#  Text(0.07541605224352223, 0.40476190476190477, 'sql <= 0.5\ngini = 0.387\nsamples = 42\nvalue = [11, 31]'),
#  Text(0.06488308405308615, 0.35714285714285715, 'age <= 32.5\ngini = 0.32\nsamples = 25\nvalue = [5, 20]'),
#  Text(0.06319780914261638, 0.30952380952380953, 'education <= 14.0\ngini = 0.351\nsamples = 22\nvalue = [5, 17]'),
#  Text(0.059827259321676846, 0.2619047619047619, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.058141984411207076, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06151253423214662, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06656835896355592, 0.2619047619047619, 'years_exp <= 2.5\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.06488308405308615, 0.21428571428571427, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.06825363387402571, 0.21428571428571427, 'Q3_India <= 0.5\ngini = 0.408\nsamples = 14\nvalue = [4, 10]'),
#  Text(0.06656835896355592, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.06993890878449548, 0.16666666666666666, 'compensation <= 5000.0\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.06572572150832104, 0.11904761904761904, 'age <= 27.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.06235517168738151, 0.07142857142857142, 'years_exp <= 3.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.06066989677691173, 0.023809523809523808, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.06404044659785127, 0.023809523809523808, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06909627132926059, 0.07142857142857142, 'years_exp <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06741099641879081, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07078154623973036, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0741520960606699, 0.11904761904761904, 'major_eng <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.07246682115020013, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07583737097113967, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.06656835896355592, 0.30952380952380953, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08594902043395829, 0.35714285714285715, 'python <= 0.5\ngini = 0.457\nsamples = 17\nvalue = [6, 11]'),
#  Text(0.08426374552348852, 0.30952380952380953, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.08763429534442806, 0.30952380952380953, 'compensation <= 15000.0\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.08594902043395829, 0.2619047619047619, 'compensation <= 5000.0\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.08426374552348852, 0.21428571428571427, 'Q1_Female <= 0.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.08257847061301875, 0.16666666666666666, 'years_exp <= 3.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.08089319570254898, 0.11904761904761904, 'years_exp <= 2.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.07920792079207921, 0.07142857142857142, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.08257847061301875, 0.07142857142857142, 'major_eng <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.08089319570254898, 0.023809523809523808, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08426374552348852, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08426374552348852, 0.11904761904761904, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.08594902043395829, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08763429534442806, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08931957025489783, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07878660206446177, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08763429534442806, 0.5, 'compensation <= 25000.0\ngini = 0.08\nsamples = 24\nvalue = [1, 23]'),
#  Text(0.08594902043395829, 0.4523809523809524, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.08931957025489783, 0.4523809523809524, 'Q3_India <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.08763429534442806, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0910048451653676, 0.40476190476190477, 'python <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08931957025489783, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09269012007583737, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08099852538445333, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.144564988413735, 0.6904761904761905, 'education <= 19.5\ngini = 0.487\nsamples = 110\nvalue = [46, 64]'),
#  Text(0.13640193806614703, 0.6428571428571429, 'education <= 18.5\ngini = 0.477\nsamples = 102\nvalue = [40.0, 62.0]'),
#  Text(0.12850221192331998, 0.5952380952380952, 'sql <= 0.5\ngini = 0.487\nsamples = 93\nvalue = [39.0, 54.0]'),
#  Text(0.1177585843690752, 0.5476190476190477, 'compensation <= 15000.0\ngini = 0.461\nsamples = 61\nvalue = [22, 39]'),
#  Text(0.11354539709290078, 0.5, 'years_exp <= 7.5\ngini = 0.495\nsamples = 40\nvalue = [18, 22]'),
#  Text(0.11186012218243101, 0.4523809523809524, 'age <= 32.5\ngini = 0.497\nsamples = 39\nvalue = [18, 21]'),
#  Text(0.11017484727196124, 0.40476190476190477, 'years_exp <= 3.5\ngini = 0.491\nsamples = 37\nvalue = [16, 21]'),
#  Text(0.10490836317674321, 0.35714285714285715, 'age <= 27.5\ngini = 0.477\nsamples = 28\nvalue = [11, 17]'),
#  Text(0.10322308826627344, 0.30952380952380953, 'age <= 23.5\ngini = 0.453\nsamples = 26\nvalue = [9, 17]'),
#  Text(0.09437539498630713, 0.2619047619047619, 'years_exp <= 2.5\ngini = 0.496\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.09269012007583737, 0.21428571428571427, 'major_other <= 0.5\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.08931957025489783, 0.16666666666666666, 'python <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.08763429534442806, 0.11904761904761904, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.0910048451653676, 0.11904761904761904, 'compensation <= 5000.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.08931957025489783, 0.07142857142857142, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.09269012007583737, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09606066989677692, 0.16666666666666666, 'years_exp <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.09437539498630713, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09774594480724669, 0.11904761904761904, 'python <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09606066989677692, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09943121971771646, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09606066989677692, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11207078154623973, 0.2619047619047619, 'Q1_Male <= 0.5\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.1078575942700653, 0.21428571428571427, 'Q3_China <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.10617231935959554, 0.16666666666666666, 'major_other <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.10448704444912577, 0.11904761904761904, 'python <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.102801769538656, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10617231935959554, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1078575942700653, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10954286918053507, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11628396882241415, 0.21428571428571427, 'python <= 0.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.11459869391194438, 0.16666666666666666, 'years_exp <= 2.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.11291341900147461, 0.11904761904761904, 'Q3_India <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.10954286918053507, 0.07142857142857142, 'years_exp <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1078575942700653, 0.023809523809523808, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11122814409100484, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11628396882241415, 0.07142857142857142, 'years_exp <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11459869391194438, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11796924373288392, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11628396882241415, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11796924373288392, 0.16666666666666666, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.10659363808721298, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11544133136717927, 0.35714285714285715, 'age <= 27.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.1137560564567095, 0.30952380952380953, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.11712660627764904, 0.30952380952380953, 'major_other <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.11544133136717927, 0.2619047619047619, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1188118811881188, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.11354539709290078, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11523067200337055, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12197177164524964, 0.5, 'age <= 32.5\ngini = 0.308\nsamples = 21\nvalue = [4, 17]'),
#  Text(0.11860122182431009, 0.4523809523809524, 'compensation <= 75000.0\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.11691594691384032, 0.40476190476190477, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.12028649673477985, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12534232146618918, 0.4523809523809524, 'years_exp <= 12.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.12365704655571941, 0.40476190476190477, 'years_exp <= 7.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.12197177164524964, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12534232146618918, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.12702759637665895, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13924583947756478, 0.5476190476190477, 'years_exp <= 3.5\ngini = 0.498\nsamples = 32\nvalue = [17, 15]'),
#  Text(0.13376869601853802, 0.5, 'compensation <= 107500.0\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.13208342110806826, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.13039814619759849, 0.40476190476190477, 'age <= 27.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.12871287128712872, 0.35714285714285715, 'major_eng <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.12702759637665895, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13039814619759849, 0.30952380952380953, 'age <= 23.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.12871287128712872, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13208342110806826, 0.2619047619047619, 'Q3_China <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.13039814619759849, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13376869601853802, 0.21428571428571427, 'years_exp <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.13208342110806826, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1354539709290078, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13208342110806826, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13376869601853802, 0.40476190476190477, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.1354539709290078, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14472298293659153, 0.5, 'compensation <= 35000.0\ngini = 0.444\nsamples = 15\nvalue = [5, 10]'),
#  Text(0.1405097956604171, 0.4523809523809524, 'years_exp <= 7.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.13713924583947756, 0.40476190476190477, 'major_eng <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.1354539709290078, 0.35714285714285715, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.13882452074994733, 0.35714285714285715, 'Q1_Male <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.13713924583947756, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1405097956604171, 0.30952380952380953, 'Q3_China <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.13882452074994733, 0.2619047619047619, 'years_exp <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.13713924583947756, 0.21428571428571427, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1405097956604171, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14219507057088687, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14388034548135664, 0.40476190476190477, 'compensation <= 25000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.14219507057088687, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1455656203918264, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14893617021276595, 0.4523809523809524, 'compensation <= 90000.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.14725089530229618, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.15062144512323572, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14430166420897408, 0.5952380952380952, 'age <= 32.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.14261638929850431, 0.5476190476190477, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.14598693911944385, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15272803876132293, 0.6428571428571429, 'python <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.15104276385085316, 0.5952380952380952, 'Q3_China <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1493574889403834, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15272803876132293, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1544133136717927, 0.5952380952380952, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.16452496313461135, 0.7380952380952381, 'sql <= 0.5\ngini = 0.436\nsamples = 28\nvalue = [19, 9]'),
#  Text(0.16115441331367178, 0.6904761904761905, 'years_exp <= 7.5\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.159469138403202, 0.6428571428571429, 'python <= 0.5\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.15778386349273224, 0.5952380952380952, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.16115441331367178, 0.5952380952380952, 'compensation <= 15000.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.159469138403202, 0.5476190476190477, 'age <= 20.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.15778386349273224, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16115441331367178, 0.5, 'education <= 17.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.159469138403202, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.16283968822414158, 0.4523809523809524, 'Q3_India <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.16115441331367178, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16452496313461135, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16283968822414158, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16283968822414158, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16789551295555089, 0.6904761904761905, 'Q1_Male <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.16621023804508112, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16958078786602065, 0.6428571428571429, 'compensation <= 15000.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.16789551295555089, 0.5952380952380952, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.17126606277649042, 0.5952380952380952, 'age <= 27.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.16958078786602065, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1729513376869602, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3165288603328418, 0.8333333333333334, 'years_exp <= 4.5\ngini = 0.434\nsamples = 396\nvalue = [270, 126]'),
#  Text(0.2758847693279966, 0.7857142857142857, 'major_eng <= 0.5\ngini = 0.363\nsamples = 294\nvalue = [224, 70]'),
#  Text(0.24062565831051191, 0.7380952380952381, 'education <= 19.5\ngini = 0.303\nsamples = 204\nvalue = [166, 38]'),
#  Text(0.21560985885822626, 0.6904761904761905, 'years_exp <= 1.5\ngini = 0.348\nsamples = 147\nvalue = [114, 33]'),
#  Text(0.19886243943543291, 0.6428571428571429, 'education <= 18.5\ngini = 0.263\nsamples = 77\nvalue = [65, 12]'),
#  Text(0.19717716452496314, 0.5952380952380952, 'Q1_Prefer to self-describe <= 0.5\ngini = 0.248\nsamples = 76\nvalue = [65, 11]'),
#  Text(0.19549188961449337, 0.5476190476190477, 'age <= 37.5\ngini = 0.231\nsamples = 75\nvalue = [65, 10]'),
#  Text(0.1860122182431009, 0.5, 'compensation <= 75000.0\ngini = 0.205\nsamples = 69\nvalue = [61, 8]'),
#  Text(0.17547925005266485, 0.4523809523809524, 'major_other <= 0.5\ngini = 0.278\nsamples = 30\nvalue = [25, 5]'),
#  Text(0.16789551295555089, 0.40476190476190477, 'compensation <= 65000.0\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.16621023804508112, 0.35714285714285715, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.16958078786602065, 0.35714285714285715, 'age <= 23.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.16789551295555089, 0.30952380952380953, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.17126606277649042, 0.30952380952380953, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.16958078786602065, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1729513376869602, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1830629871497788, 0.40476190476190477, 'education <= 17.0\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(0.18137771223930904, 0.35714285714285715, 'age <= 23.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.1780071624183695, 0.30952380952380953, 'compensation <= 60000.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.17632188750789973, 0.2619047619047619, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.17969243732883927, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18474826206024858, 0.30952380952380953, 'compensation <= 65000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.1830629871497788, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.18643353697071835, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18474826206024858, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.19654518643353697, 0.4523809523809524, 'major_stat <= 0.5\ngini = 0.142\nsamples = 39\nvalue = [36, 3]'),
#  Text(0.19148936170212766, 0.40476190476190477, 'compensation <= 112500.0\ngini = 0.067\nsamples = 29\nvalue = [28, 1]'),
#  Text(0.1898040867916579, 0.35714285714285715, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.19317463661259743, 0.35714285714285715, 'sql <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.19148936170212766, 0.30952380952380953, 'compensation <= 137500.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1898040867916579, 0.2619047619047619, 'age <= 23.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.18811881188118812, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19148936170212766, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19317463661259743, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1948599115230672, 0.30952380952380953, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.20160101116494628, 0.40476190476190477, 'compensation <= 112500.0\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.1999157362544765, 0.35714285714285715, 'Q1_Male <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.19823046134400674, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20160101116494628, 0.30952380952380953, 'education <= 17.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.1999157362544765, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.20328628607541605, 0.2619047619047619, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.20328628607541605, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.20497156098588581, 0.5, 'compensation <= 30000.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.20328628607541605, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.20665683589635558, 0.4523809523809524, 'age <= 45.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.20497156098588581, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.20834211080682535, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19886243943543291, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20054771434590268, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2323572782810196, 0.6428571428571429, 'compensation <= 75000.0\ngini = 0.42\nsamples = 70\nvalue = [49, 21]'),
#  Text(0.22266694754581842, 0.5952380952380952, 'compensation <= 10000.0\ngini = 0.499\nsamples = 25\nvalue = [13, 12]'),
#  Text(0.218453760269644, 0.5476190476190477, 'age <= 27.5\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.21508321044870443, 0.5, 'education <= 17.0\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.21339793553823466, 0.4523809523809524, 'years_exp <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2117126606277649, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21508321044870443, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21676848535917423, 0.4523809523809524, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.22182431009058354, 0.5, 'Q1_Female <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.22013903518011377, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.2235095850010533, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.22688013482199285, 0.5476190476190477, 'years_exp <= 3.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.22519485991152308, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.22856540973246262, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24204760901622077, 0.5952380952380952, 'sql <= 0.5\ngini = 0.32\nsamples = 45\nvalue = [36, 9]'),
#  Text(0.23699178428481146, 0.5476190476190477, 'compensation <= 112500.0\ngini = 0.413\nsamples = 24\nvalue = [17, 7]'),
#  Text(0.23193595955340215, 0.5, 'education <= 17.0\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.22688013482199285, 0.4523809523809524, 'education <= 12.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.22519485991152308, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.22856540973246262, 0.40476190476190477, 'years_exp <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.22688013482199285, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.23025068464293239, 0.35714285714285715, 'age <= 32.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.22856540973246262, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23193595955340215, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23699178428481146, 0.4523809523809524, 'years_exp <= 3.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.2353065093743417, 0.40476190476190477, 'Q1_Male <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.23362123446387192, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23699178428481146, 0.35714285714285715, 'age <= 27.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.2353065093743417, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.23867705919528123, 0.30952380952380953, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.23867705919528123, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24204760901622077, 0.5, 'Q1_Prefer not to say <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.240362334105751, 0.4523809523809524, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.24373288392669054, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.24710343374763008, 0.5476190476190477, 'compensation <= 137500.0\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.2454181588371603, 0.5, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.24878870865809985, 0.5, 'major_stat <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.24710343374763008, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.25047398356856965, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2656414577627976, 0.6904761904761905, 'compensation <= 137500.0\ngini = 0.16\nsamples = 57\nvalue = [52, 5]'),
#  Text(0.2572150832104487, 0.6428571428571429, 'age <= 27.5\ngini = 0.083\nsamples = 46\nvalue = [44, 2]'),
#  Text(0.2521592584790394, 0.5952380952380952, 'compensation <= 90000.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.25047398356856965, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2538445333895092, 0.5476190476190477, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2521592584790394, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.25552980829997896, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26227090794185803, 0.5952380952380952, 'age <= 32.5\ngini = 0.05\nsamples = 39\nvalue = [38, 1]'),
#  Text(0.26058563303138826, 0.5476190476190477, 'sql <= 0.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.2589003581209185, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.26227090794185803, 0.5, 'years_exp <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.26058563303138826, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2639561828523278, 0.4523809523809524, 'years_exp <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.26227090794185803, 0.40476190476190477, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.26058563303138826, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2639561828523278, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2656414577627976, 0.40476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2639561828523278, 0.5476190476190477, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.2740678323151464, 0.6428571428571429, 'Q1_Female <= 0.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.27238255740467665, 0.5952380952380952, 'sql <= 0.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.2706972824942069, 0.5476190476190477, 'major_stat <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.2690120075837371, 0.5, 'years_exp <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.26732673267326734, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2706972824942069, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.27238255740467665, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2740678323151464, 0.5476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.2757531072256162, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.31114388034548135, 0.7380952380952381, 'compensation <= 112500.0\ngini = 0.458\nsamples = 90\nvalue = [58.0, 32.0]'),
#  Text(0.3035601432483674, 0.6904761904761905, 'years_exp <= 3.5\ngini = 0.489\nsamples = 66\nvalue = [38, 28]'),
#  Text(0.3018748683378976, 0.6428571428571429, 'age <= 37.5\ngini = 0.475\nsamples = 62\nvalue = [38, 24]'),
#  Text(0.29344849378554877, 0.5952380952380952, 'years_exp <= 0.5\ngini = 0.456\nsamples = 57\nvalue = [37, 20]'),
#  Text(0.2816515694122604, 0.5476190476190477, 'age <= 32.5\ngini = 0.491\nsamples = 23\nvalue = [13.0, 10.0]'),
#  Text(0.2799662945017906, 0.5, 'Q1_Female <= 0.5\ngini = 0.483\nsamples = 22\nvalue = [13, 9]'),
#  Text(0.2740678323151464, 0.4523809523809524, 'age <= 23.5\ngini = 0.457\nsamples = 17\nvalue = [11, 6]'),
#  Text(0.2706972824942069, 0.40476190476190477, 'sql <= 0.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.2690120075837371, 0.35714285714285715, 'compensation <= 75000.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.26732673267326734, 0.30952380952380953, 'education <= 19.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.2656414577627976, 0.2619047619047619, 'education <= 17.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.2639561828523278, 0.21428571428571427, 'python <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.26227090794185803, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2656414577627976, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.26732673267326734, 0.21428571428571427, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2690120075837371, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2706972824942069, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.27238255740467665, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.27743838213608596, 0.40476190476190477, 'compensation <= 60000.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.2757531072256162, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.27912365704655573, 0.35714285714285715, 'compensation <= 85000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.27743838213608596, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2808089319570255, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2858647566884348, 0.4523809523809524, 'sql <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.28417948177796504, 0.40476190476190477, 'compensation <= 45000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.28249420686749527, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2858647566884348, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2875500315989046, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.28333684432273015, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30524541815883716, 0.5476190476190477, 'age <= 32.5\ngini = 0.415\nsamples = 34\nvalue = [24, 10]'),
#  Text(0.3035601432483674, 0.5, 'compensation <= 95000.0\ngini = 0.444\nsamples = 30\nvalue = [20, 10]'),
#  Text(0.2959764061512534, 0.4523809523809524, 'Q1_Prefer not to say <= 0.5\ngini = 0.469\nsamples = 24\nvalue = [15, 9]'),
#  Text(0.29429113124078365, 0.40476190476190477, 'sql <= 0.5\ngini = 0.476\nsamples = 23\nvalue = [14, 9]'),
#  Text(0.28923530650937435, 0.35714285714285715, 'age <= 27.5\ngini = 0.444\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.2875500315989046, 0.30952380952380953, 'years_exp <= 2.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.28417948177796504, 0.2619047619047619, 'compensation <= 75000.0\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.28249420686749527, 0.21428571428571427, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.2858647566884348, 0.21428571428571427, 'compensation <= 85000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.28417948177796504, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2875500315989046, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2909205814198441, 0.2619047619047619, 'education <= 17.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.28923530650937435, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2926058563303139, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2909205814198441, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.29934695597219296, 0.35714285714285715, 'age <= 27.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.2959764061512534, 0.30952380952380953, 'compensation <= 35000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.29429113124078365, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2976616810617232, 0.2619047619047619, 'Q1_Female <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2959764061512534, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.29934695597219296, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3027175057931325, 0.30952380952380953, 'education <= 19.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.30103223088266273, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.30440278070360227, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2976616810617232, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.31114388034548135, 0.4523809523809524, 'sql <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.3094586054350116, 0.40476190476190477, 'education <= 19.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3077733305245418, 0.35714285714285715, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.30608805561407204, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3094586054350116, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.31114388034548135, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3128291552559511, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3069306930693069, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.31030124289024646, 0.5952380952380952, 'education <= 19.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.3086159679797767, 0.5476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.31198651780071623, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.30524541815883716, 0.6428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3187276174425953, 0.6904761904761905, 'education <= 17.0\ngini = 0.278\nsamples = 24\nvalue = [20, 4]'),
#  Text(0.3153570676216558, 0.6428571428571429, 'age <= 23.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.313671792711186, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.31704234253212554, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.32209816726353485, 0.6428571428571429, 'age <= 27.5\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.3204128923530651, 0.5952380952380952, 'years_exp <= 3.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.3187276174425953, 0.5476190476190477, 'years_exp <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.31704234253212554, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3204128923530651, 0.5, 'sql <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.3187276174425953, 0.4523809523809524, 'compensation <= 137500.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.31704234253212554, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3204128923530651, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.32209816726353485, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.32209816726353485, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3237834421740046, 0.5952380952380952, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.35717295133768695, 0.7857142857142857, 'education <= 18.5\ngini = 0.495\nsamples = 102\nvalue = [46.0, 56.0]'),
#  Text(0.3400042131872762, 0.7380952380952381, 'education <= 17.0\ngini = 0.438\nsamples = 74\nvalue = [24, 50]'),
#  Text(0.3305245418158837, 0.6904761904761905, 'major_other <= 0.5\ngini = 0.165\nsamples = 22\nvalue = [2, 20]'),
#  Text(0.32883926690541393, 0.6428571428571429, 'age <= 40.0\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.32715399199494416, 0.5952380952380952, 'compensation <= 65000.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.3254687170844744, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.32883926690541393, 0.5476190476190477, 'compensation <= 137500.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.32715399199494416, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3305245418158837, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3305245418158837, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.33220981672635347, 0.6428571428571429, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.34948388455866863, 0.6904761904761905, 'compensation <= 112500.0\ngini = 0.488\nsamples = 52\nvalue = [22.0, 30.0]'),
# ...
#  Text(0.6191278702338319, 0.5, 'Q3_China <= 0.5\ngini = 0.48\nsamples = 25\nvalue = [15, 10]'),
#  Text(0.6123867705919528, 0.4523809523809524, 'years_exp <= 1.5\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.610701495681483, 0.40476190476190477, 'compensation <= 112500.0\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.6073309458605435, 0.35714285714285715, 'sql <= 0.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.6056456709500737, 0.30952380952380953, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6090162207710133, 0.30952380952380953, 'years_exp <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.6073309458605435, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.610701495681483, 0.2619047619047619, 'compensation <= 75000.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.6090162207710133, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6123867705919528, 0.21428571428571427, 'compensation <= 90000.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.610701495681483, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6140720455024226, 0.16666666666666666, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6140720455024226, 0.35714285714285715, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6123867705919528, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6157573204128923, 0.30952380952380953, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6140720455024226, 0.40476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.625868969875711, 0.4523809523809524, 'sql <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.6241836949652412, 0.40476190476190477, 'age <= 27.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.6208131451443016, 0.35714285714285715, 'compensation <= 35000.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6191278702338319, 0.30952380952380953, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6224984200547714, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6275542447861807, 0.35714285714285715, 'compensation <= 80000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.625868969875711, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6292395196966505, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6275542447861807, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6309247946071203, 0.5, 'Q3_United States of America <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6292395196966505, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.63261006951759, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6283968822414157, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6300821571518854, 0.5952380952380952, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.7072460238045081, 0.8333333333333334, 'education <= 17.0\ngini = 0.334\nsamples = 293\nvalue = [62, 231]'),
#  Text(0.6603907731198652, 0.7857142857142857, 'Q3_China <= 0.5\ngini = 0.233\nsamples = 134\nvalue = [18.0, 116.0]'),
#  Text(0.6542553191489362, 0.7380952380952381, 'years_exp <= 12.5\ngini = 0.203\nsamples = 122\nvalue = [14, 108]'),
#  Text(0.6525700442384664, 0.6904761904761905, 'age <= 42.5\ngini = 0.226\nsamples = 108\nvalue = [14, 94]'),
#  Text(0.6470402359384875, 0.6428571428571429, 'years_exp <= 3.5\ngini = 0.215\nsamples = 106\nvalue = [13, 93]'),
#  Text(0.6410364440699389, 0.5952380952380952, 'compensation <= 90000.0\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.6393511691594691, 0.5476190476190477, 'age <= 32.5\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(0.6376658942489993, 0.5, 'python <= 0.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(0.6359806193385296, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6342953444280598, 0.40476190476190477, 'age <= 21.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.63261006951759, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6359806193385296, 0.35714285714285715, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6376658942489993, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6393511691594691, 0.4523809523809524, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.6410364440699389, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6427217189804086, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6530440278070361, 0.5952380952380952, 'Q3_India <= 0.5\ngini = 0.187\nsamples = 86\nvalue = [9, 77]'),
#  Text(0.6513587528965663, 0.5476190476190477, 'gini = 0.0\nsamples = 30\nvalue = [0, 30]'),
#  Text(0.6547293027175058, 0.5476190476190477, 'compensation <= 85000.0\ngini = 0.27\nsamples = 56\nvalue = [9, 47]'),
#  Text(0.6490414998946703, 0.5, 'compensation <= 5000.0\ngini = 0.252\nsamples = 54\nvalue = [8, 46]'),
#  Text(0.6427217189804086, 0.4523809523809524, 'age <= 32.5\ngini = 0.33\nsamples = 24\nvalue = [5, 19]'),
#  Text(0.6410364440699389, 0.40476190476190477, 'Q1_Male <= 0.5\ngini = 0.363\nsamples = 21\nvalue = [5, 16]'),
#  Text(0.6393511691594691, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6427217189804086, 0.35714285714285715, 'python <= 0.5\ngini = 0.401\nsamples = 18\nvalue = [5, 13]'),
#  Text(0.6368232567937645, 0.30952380952380953, 'years_exp <= 4.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.6351379818832947, 0.2619047619047619, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6385085317042343, 0.2619047619047619, 'years_exp <= 7.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6368232567937645, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.640193806614704, 0.21428571428571427, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6486201811670529, 0.30952380952380953, 'years_exp <= 7.5\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.6452496313461134, 0.2619047619047619, 'sql <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.6435643564356436, 0.21428571428571427, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.6469349062565831, 0.21428571428571427, 'years_exp <= 4.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6452496313461134, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6486201811670529, 0.16666666666666666, 'age <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6469349062565831, 0.11904761904761904, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6503054560775227, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6519907309879924, 0.2619047619047619, 'age <= 24.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6503054560775227, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6536760058984622, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6444069938908784, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.655361280808932, 0.4523809523809524, 'compensation <= 15000.0\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.6536760058984622, 0.40476190476190477, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.6570465557194017, 0.40476190476190477, 'Q1_Male <= 0.5\ngini = 0.255\nsamples = 20\nvalue = [3, 17]'),
#  Text(0.6536760058984622, 0.35714285714285715, 'age <= 27.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6519907309879924, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.655361280808932, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6604171055403413, 0.35714285714285715, 'sql <= 0.5\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(0.6587318306298715, 0.30952380952380953, 'age <= 27.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.6570465557194017, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6604171055403413, 0.2619047619047619, 'compensation <= 50000.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6587318306298715, 0.21428571428571427, 'years_exp <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6570465557194017, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6604171055403413, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.662102380450811, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.662102380450811, 0.30952380952380953, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.6604171055403413, 0.5, 'sql <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6587318306298715, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.662102380450811, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6580998525384454, 0.6428571428571429, 'years_exp <= 7.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6564145776279756, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6597851274489152, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.655940594059406, 0.6904761904761905, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.6665262270907942, 0.7380952380952381, 'sql <= 0.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.6631556772698547, 0.6904761904761905, 'age <= 32.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.6614704023593849, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6648409521803245, 0.6428571428571429, 'years_exp <= 4.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6631556772698547, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6665262270907942, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6698967769117338, 0.6904761904761905, 'compensation <= 55000.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.668211502001264, 0.6428571428571429, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6715820518222035, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7541012744891511, 0.7857142857142857, 'age <= 20.0\ngini = 0.4\nsamples = 159\nvalue = [44.0, 115.0]'),
#  Text(0.7524159995786813, 0.7380952380952381, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7557865493996209, 0.7380952380952381, 'age <= 47.5\ngini = 0.392\nsamples = 157\nvalue = [42.0, 115.0]'),
#  Text(0.7449836738993049, 0.6904761904761905, 'years_exp <= 7.5\ngini = 0.375\nsamples = 148\nvalue = [37, 111]'),
#  Text(0.7334895723614915, 0.6428571428571429, 'education <= 19.5\ngini = 0.422\nsamples = 109\nvalue = [33, 76]'),
#  Text(0.7206130187486833, 0.5952380952380952, 'age <= 37.5\ngini = 0.397\nsamples = 99\nvalue = [27.0, 72.0]'),
#  Text(0.7066568358963556, 0.5476190476190477, 'age <= 27.5\ngini = 0.372\nsamples = 93\nvalue = [23, 70]'),
#  Text(0.6869601853802402, 0.5, 'education <= 18.5\ngini = 0.427\nsamples = 42\nvalue = [13, 29]'),
#  Text(0.6852749104697704, 0.4523809523809524, 'compensation <= 5000.0\ngini = 0.414\nsamples = 41\nvalue = [12, 29]'),
#  Text(0.6747419422793343, 0.40476190476190477, 'years_exp <= 4.5\ngini = 0.298\nsamples = 22\nvalue = [4, 18]'),
#  Text(0.6730566673688645, 0.35714285714285715, 'python <= 0.5\ngini = 0.332\nsamples = 19\nvalue = [4, 15]'),
#  Text(0.6688434800926901, 0.30952380952380953, 'years_exp <= 3.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6671582051822204, 0.2619047619047619, 'Q3_China <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6654729302717506, 0.21428571428571427, 'age <= 23.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6637876553612808, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6671582051822204, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6688434800926901, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6705287550031599, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.677269854645039, 0.30952380952380953, 'years_exp <= 3.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.6738993048240994, 0.2619047619047619, 'Q3_United States of America <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.6722140299136297, 0.21428571428571427, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.6755845797345692, 0.21428571428571427, 'sql <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6738993048240994, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.677269854645039, 0.16666666666666666, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6755845797345692, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6789551295555087, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6806404044659785, 0.2619047619047619, 'Q1_Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6789551295555087, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6823256793764483, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6764272171898041, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6958078786602064, 0.40476190476190477, 'compensation <= 125000.0\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.6941226037497367, 0.35714285714285715, 'years_exp <= 4.5\ngini = 0.5\nsamples = 16\nvalue = [8, 8]'),
#  Text(0.6924373288392669, 0.30952380952380953, 'python <= 0.5\ngini = 0.498\nsamples = 15\nvalue = [7, 8]'),
#  Text(0.6873815041078576, 0.2619047619047619, 'compensation <= 60000.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6856962291973878, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6890667790183274, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6974931535706762, 0.2619047619047619, 'compensation <= 45000.0\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.6924373288392669, 0.21428571428571427, 'sql <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.6907520539287971, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6941226037497367, 0.16666666666666666, 'years_exp <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6924373288392669, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6958078786602064, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7025489783020855, 0.21428571428571427, 'Q3_United States of America <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.7008637033916157, 0.16666666666666666, 'compensation <= 55000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.699178428481146, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7025489783020855, 0.11904761904761904, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7042342532125553, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6958078786602064, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6974931535706762, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6886454602907099, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.726353486412471, 0.5, 'compensation <= 112500.0\ngini = 0.315\nsamples = 51\nvalue = [10, 41]'),
#  Text(0.7215083210448704, 0.4523809523809524, 'compensation <= 75000.0\ngini = 0.263\nsamples = 45\nvalue = [7, 38]'),
#  Text(0.7198230461344006, 0.40476190476190477, 'Q1_Female <= 0.5\ngini = 0.313\nsamples = 36\nvalue = [7, 29]'),
#  Text(0.7151885401306088, 0.35714285714285715, 'age <= 32.5\ngini = 0.257\nsamples = 33\nvalue = [5, 28]'),
#  Text(0.7109753528544344, 0.30952380952380953, 'years_exp <= 3.5\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.7076048030334948, 0.2619047619047619, 'python <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  ...]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
features = list(c for c in X_train.columns)
tree.plot_tree(hi_variance, feature_names=features, filled=True, 
                  class_names=hi_variance.classes_,
                max_depth=2, fontsize=6)
# Out:
# [Text(0.5, 0.875, 'r <= 0.5\ngini = 0.496\nsamples = 2110\nvalue = [1153, 957]\nclass = Data Scientist'),
#  Text(0.25, 0.625, 'major_cs <= 0.5\ngini = 0.493\nsamples = 1484\nvalue = [653, 831]\nclass = Software Engineer'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, 'Q3_United States of America <= 0.5\ngini = 0.49\nsamples = 718\nvalue = [410, 308]\nclass = Data Scientist'),
#  Text(0.0625, 0.125, '\n  (...)  \n'),
#  Text(0.1875, 0.125, '\n  (...)  \n'),
#  Text(0.375, 0.375, 'years_exp <= 2.5\ngini = 0.433\nsamples = 766\nvalue = [243.0, 523.0]\nclass = Software Engineer'),
#  Text(0.3125, 0.125, '\n  (...)  \n'),
#  Text(0.4375, 0.125, '\n  (...)  \n'),
#  Text(0.75, 0.625, 'major_cs <= 0.5\ngini = 0.322\nsamples = 626\nvalue = [500.0, 126.0]\nclass = Data Scientist'),
#  Text(0.625, 0.75, '  False'),
#  Text(0.625, 0.375, 'years_exp <= 22.5\ngini = 0.211\nsamples = 443\nvalue = [390, 53]\nclass = Data Scientist'),
#  Text(0.5625, 0.125, '\n  (...)  \n'),
#  Text(0.6875, 0.125, '\n  (...)  \n'),
#  Text(0.875, 0.375, 'years_exp <= 7.5\ngini = 0.48\nsamples = 183\nvalue = [110, 73]\nclass = Data Scientist'),
#  Text(0.8125, 0.125, '\n  (...)  \n'),
#  Text(0.9375, 0.125, '\n  (...)  \n')]

# %% [markdown]
# ## Tree Hyperparameters

# %%
underfit.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 1,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
accuracies = []
for depth in range(1, 15):
    between = tree.DecisionTreeClassifier(max_depth=depth)
    between.fit(X_train, kag_y_train)
    accuracies.append(between.score(X_test, kag_y_test))

# %%
fig, ax = plt.subplots(figsize=(10,4))    
(pd.Series(accuracies, name='Accuracy', index=range(1, len(accuracies)+1))
 .plot(ax=ax, title='Accuracy at a given Tree Depth'))
ax.set_ylabel('Accuracy')
ax.set_xlabel('max_depth')
# Out:
# Text(0.5, 0, 'max_depth')

# %%
between = tree.DecisionTreeClassifier(max_depth=7)
between.fit(X_train, kag_y_train)
between.score(X_test, kag_y_test)
# Out:
# 0.7337016574585635

# %%
from yellowbrick.model_selection import validation_curve
fig, ax = plt.subplots(figsize=(10,4))    
viz = validation_curve(tree.DecisionTreeClassifier(),
    X=pd.concat([X_train, X_test]),
    y=pd.concat([kag_y_train, kag_y_test]),   
    param_name='max_depth', param_range=range(1,14),
    scoring='accuracy', cv=5, ax=ax, n_jobs=6)
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif

# %% [markdown]
# ### Grid Search

# %%
from sklearn.model_selection import GridSearchCV
params = {
    'max_depth': [3, 5, 7, 8],
    'min_samples_leaf': [1, 3, 4, 5, 6],
    'min_samples_split': [2, 3, 4, 5, 6],
}
grid_search = GridSearchCV(estimator=tree.DecisionTreeClassifier(), 
                           param_grid=params, cv=4, n_jobs=-1, 
                           verbose=1, scoring="accuracy")
grid_search.fit(pd.concat([X_train, X_test]),
    pd.concat([kag_y_train, kag_y_test]))
# Out:
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 7, 8],
#                          'min_samples_leaf': [1, 3, 4, 5, 6],
#                          'min_samples_split': [2, 3, 4, 5, 6]},
#              scoring='accuracy', verbose=1)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 2}

# %%
between2 = tree.DecisionTreeClassifier(**grid_search.best_params_)
between2.fit(X_train, kag_y_train)
between2.score(X_test, kag_y_test)
# Out:
# 0.7259668508287292

# %%
(pd.DataFrame(grid_search.cv_results_)
 .sort_values(by='rank_test_score')
 .style
 .background_gradient(axis='rows')
)
# Out:
# <style type="text/css">
# #T_ce78b_row0_col0, #T_ce78b_row10_col13 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_ce78b_row0_col1, #T_ce78b_row19_col13, #T_ce78b_row27_col13 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_ce78b_row0_col2, #T_ce78b_row15_col0 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_ce78b_row0_col3, #T_ce78b_row1_col1, #T_ce78b_row39_col2, #T_ce78b_row41_col3, #T_ce78b_row75_col12, #T_ce78b_row76_col12, #T_ce78b_row77_col12, #T_ce78b_row78_col12, #T_ce78b_row79_col12, #T_ce78b_row80_col12, #T_ce78b_row81_col12, #T_ce78b_row82_col12, #T_ce78b_row83_col12, #T_ce78b_row84_col12, #T_ce78b_row85_col12, #T_ce78b_row86_col12, #T_ce78b_row87_col12, #T_ce78b_row88_col12, #T_ce78b_row89_col12, #T_ce78b_row99_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_ce78b_row0_col4, #T_ce78b_row0_col5, #T_ce78b_row1_col4, #T_ce78b_row1_col5, #T_ce78b_row2_col4, #T_ce78b_row2_col5, #T_ce78b_row3_col4, #T_ce78b_row3_col5, #T_ce78b_row4_col4, #T_ce78b_row4_col5, #T_ce78b_row5_col4, #T_ce78b_row6_col4, #T_ce78b_row7_col4, #T_ce78b_row8_col0, #T_ce78b_row8_col4, #T_ce78b_row9_col4, #T_ce78b_row10_col4, #T_ce78b_row11_col4, #T_ce78b_row12_col4, #T_ce78b_row13_col4, #T_ce78b_row14_col4, #T_ce78b_row15_col4, #T_ce78b_row16_col4, #T_ce78b_row17_col4, #T_ce78b_row18_col4, #T_ce78b_row19_col4, #T_ce78b_row22_col0, #T_ce78b_row22_col4, #T_ce78b_row23_col5, #T_ce78b_row24_col4, #T_ce78b_row25_col4, #T_ce78b_row27_col4, #T_ce78b_row28_col5, #T_ce78b_row29_col5, #T_ce78b_row30_col5, #T_ce78b_row31_col5, #T_ce78b_row32_col4, #T_ce78b_row39_col11, #T_ce78b_row40_col11, #T_ce78b_row41_col11, #T_ce78b_row43_col11, #T_ce78b_row44_col11, #T_ce78b_row53_col11, #T_ce78b_row55_col11, #T_ce78b_row56_col11, #T_ce78b_row58_col11, #T_ce78b_row60_col5, #T_ce78b_row61_col5, #T_ce78b_row62_col5, #T_ce78b_row63_col5, #T_ce78b_row67_col5, #T_ce78b_row72_col14, #T_ce78b_row82_col5, #T_ce78b_row83_col5, #T_ce78b_row84_col5, #T_ce78b_row85_col5, #T_ce78b_row86_col5 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_ce78b_row0_col6, #T_ce78b_row6_col6, #T_ce78b_row7_col6, #T_ce78b_row23_col6, #T_ce78b_row24_col6, #T_ce78b_row26_col6, #T_ce78b_row32_col6, #T_ce78b_row35_col6, #T_ce78b_row40_col6, #T_ce78b_row49_col6, #T_ce78b_row52_col6, #T_ce78b_row56_col6, #T_ce78b_row63_col6, #T_ce78b_row70_col6, #T_ce78b_row71_col12, #T_ce78b_row74_col6, #T_ce78b_row78_col6, #T_ce78b_row83_col6, #T_ce78b_row88_col6, #T_ce78b_row90_col6, #T_ce78b_row94_col6 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_ce78b_row0_col8, #T_ce78b_row1_col8, #T_ce78b_row2_col8, #T_ce78b_row4_col8, #T_ce78b_row9_col8, #T_ce78b_row12_col10, #T_ce78b_row14_col10, #T_ce78b_row18_col10, #T_ce78b_row65_col8, #T_ce78b_row70_col8, #T_ce78b_row73_col8 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_ce78b_row0_col9, #T_ce78b_row0_col12, #T_ce78b_row1_col6, #T_ce78b_row1_col9, #T_ce78b_row1_col12, #T_ce78b_row2_col10, #T_ce78b_row2_col12, #T_ce78b_row3_col9, #T_ce78b_row5_col5, #T_ce78b_row6_col5, #T_ce78b_row8_col5, #T_ce78b_row8_col6, #T_ce78b_row9_col6, #T_ce78b_row10_col5, #T_ce78b_row11_col5, #T_ce78b_row12_col6, #T_ce78b_row19_col6, #T_ce78b_row20_col5, #T_ce78b_row20_col6, #T_ce78b_row20_col8, #T_ce78b_row21_col5, #T_ce78b_row21_col8, #T_ce78b_row26_col11, #T_ce78b_row29_col6, #T_ce78b_row33_col6, #T_ce78b_row33_col11, #T_ce78b_row35_col5, #T_ce78b_row36_col5, #T_ce78b_row37_col5, #T_ce78b_row43_col6, #T_ce78b_row47_col6, #T_ce78b_row50_col4, #T_ce78b_row51_col2, #T_ce78b_row51_col3, #T_ce78b_row51_col4, #T_ce78b_row51_col13, #T_ce78b_row52_col4, #T_ce78b_row53_col4, #T_ce78b_row53_col5, #T_ce78b_row54_col4, #T_ce78b_row54_col6, #T_ce78b_row55_col4, #T_ce78b_row56_col4, #T_ce78b_row56_col5, #T_ce78b_row57_col4, #T_ce78b_row57_col5, #T_ce78b_row58_col4, #T_ce78b_row58_col5, #T_ce78b_row59_col1, #T_ce78b_row59_col4, #T_ce78b_row59_col5, #T_ce78b_row59_col6, #T_ce78b_row60_col4, #T_ce78b_row61_col4, #T_ce78b_row62_col4, #T_ce78b_row62_col6, #T_ce78b_row63_col4, #T_ce78b_row64_col4, #T_ce78b_row64_col6, #T_ce78b_row65_col4, #T_ce78b_row66_col4, #T_ce78b_row67_col4, #T_ce78b_row68_col4, #T_ce78b_row69_col4, #T_ce78b_row70_col4, #T_ce78b_row71_col4, #T_ce78b_row71_col6, #T_ce78b_row72_col4, #T_ce78b_row73_col4, #T_ce78b_row74_col4, #T_ce78b_row75_col5, #T_ce78b_row75_col6, #T_ce78b_row76_col5, #T_ce78b_row81_col6, #T_ce78b_row86_col6, #T_ce78b_row87_col5, #T_ce78b_row88_col5, #T_ce78b_row89_col5, #T_ce78b_row90_col0, #T_ce78b_row90_col14, #T_ce78b_row91_col14, #T_ce78b_row92_col14, #T_ce78b_row93_col6, #T_ce78b_row93_col14, #T_ce78b_row94_col14, #T_ce78b_row95_col14, #T_ce78b_row96_col14, #T_ce78b_row97_col6, #T_ce78b_row97_col14, #T_ce78b_row98_col14, #T_ce78b_row99_col14 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ce78b_row0_col10, #T_ce78b_row1_col10, #T_ce78b_row3_col10, #T_ce78b_row4_col10, #T_ce78b_row5_col8, #T_ce78b_row7_col10, #T_ce78b_row9_col10, #T_ce78b_row15_col10, #T_ce78b_row17_col10, #T_ce78b_row64_col8 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_ce78b_row0_col11, #T_ce78b_row1_col11, #T_ce78b_row2_col11, #T_ce78b_row3_col11, #T_ce78b_row4_col11, #T_ce78b_row6_col11, #T_ce78b_row8_col11, #T_ce78b_row10_col11, #T_ce78b_row12_col11, #T_ce78b_row15_col9, #T_ce78b_row17_col9, #T_ce78b_row22_col11, #T_ce78b_row26_col9, #T_ce78b_row27_col9, #T_ce78b_row33_col9, #T_ce78b_row38_col9, #T_ce78b_row39_col9, #T_ce78b_row40_col9, #T_ce78b_row41_col9, #T_ce78b_row42_col9, #T_ce78b_row45_col9, #T_ce78b_row45_col11, #T_ce78b_row46_col11, #T_ce78b_row47_col11, #T_ce78b_row48_col9, #T_ce78b_row48_col11, #T_ce78b_row49_col9, #T_ce78b_row49_col11 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_ce78b_row0_col13, #T_ce78b_row1_col13, #T_ce78b_row5_col13, #T_ce78b_row28_col0 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_ce78b_row0_col14, #T_ce78b_row1_col14, #T_ce78b_row2_col6, #T_ce78b_row2_col14, #T_ce78b_row10_col6, #T_ce78b_row12_col5, #T_ce78b_row13_col5, #T_ce78b_row15_col6, #T_ce78b_row16_col5, #T_ce78b_row18_col6, #T_ce78b_row22_col5, #T_ce78b_row22_col6, #T_ce78b_row26_col5, #T_ce78b_row31_col6, #T_ce78b_row32_col5, #T_ce78b_row33_col5, #T_ce78b_row34_col5, #T_ce78b_row34_col6, #T_ce78b_row37_col6, #T_ce78b_row38_col5, #T_ce78b_row42_col5, #T_ce78b_row44_col6, #T_ce78b_row45_col3, #T_ce78b_row45_col6, #T_ce78b_row50_col5, #T_ce78b_row51_col5, #T_ce78b_row51_col8, #T_ce78b_row52_col5, #T_ce78b_row54_col5, #T_ce78b_row54_col8, #T_ce78b_row55_col5, #T_ce78b_row55_col6, #T_ce78b_row57_col6, #T_ce78b_row60_col6, #T_ce78b_row65_col10, #T_ce78b_row66_col6, #T_ce78b_row68_col6, #T_ce78b_row70_col10, #T_ce78b_row75_col4, #T_ce78b_row75_col9, #T_ce78b_row75_col11, #T_ce78b_row76_col4, #T_ce78b_row76_col9, #T_ce78b_row76_col11, #T_ce78b_row77_col4, #T_ce78b_row77_col6, #T_ce78b_row77_col9, #T_ce78b_row77_col11, #T_ce78b_row78_col4, #T_ce78b_row78_col9, #T_ce78b_row78_col11, #T_ce78b_row79_col4, #T_ce78b_row79_col9, #T_ce78b_row79_col11, #T_ce78b_row80_col4, #T_ce78b_row80_col9, #T_ce78b_row80_col11, #T_ce78b_row81_col4, #T_ce78b_row81_col9, #T_ce78b_row81_col11, #T_ce78b_row82_col4, #T_ce78b_row82_col6, #T_ce78b_row82_col9, #T_ce78b_row82_col11, #T_ce78b_row83_col0, #T_ce78b_row83_col1, #T_ce78b_row83_col2, #T_ce78b_row83_col4, #T_ce78b_row83_col9, #T_ce78b_row83_col11, #T_ce78b_row84_col4, #T_ce78b_row84_col9, #T_ce78b_row84_col11, #T_ce78b_row85_col4, #T_ce78b_row85_col9, #T_ce78b_row85_col11, #T_ce78b_row86_col0, #T_ce78b_row86_col4, #T_ce78b_row86_col9, #T_ce78b_row86_col11, #T_ce78b_row87_col4, #T_ce78b_row87_col6, #T_ce78b_row87_col9, #T_ce78b_row87_col11, #T_ce78b_row88_col4, #T_ce78b_row88_col9, #T_ce78b_row88_col11, #T_ce78b_row89_col4, #T_ce78b_row89_col9, #T_ce78b_row89_col11, #T_ce78b_row90_col4, #T_ce78b_row90_col5, #T_ce78b_row90_col9, #T_ce78b_row90_col11, #T_ce78b_row90_col12, #T_ce78b_row90_col13, #T_ce78b_row91_col4, #T_ce78b_row91_col5, #T_ce78b_row91_col9, #T_ce78b_row91_col11, #T_ce78b_row91_col12, #T_ce78b_row91_col13, #T_ce78b_row92_co

# %%
results = model_selection.cross_val_score(
    tree.DecisionTreeClassifier(max_depth=7),
    X=pd.concat([X_train, X_test], axis='index'),
    y=pd.concat([kag_y_train, kag_y_test], axis='index'),
    cv=4
)
print(results)
results.mean()
# Out:
# [0.69761273 0.73740053 0.70291777 0.71447543]
# 0.713101616522416
